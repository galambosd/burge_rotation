# %%
import pyranges as pr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Display all the columns of dataframes
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Pick an RBP to use for a toy example
# To do this, look at Supp. Data 4 in [Van Nostrand et al. (2020)](https://doi.org/10.1038/s41586-020-2077-3).
# Pick an RBP that...
# 1. Has many total IDR peaks
# 2. Has many peaks near 5' and 3' splice sites
# 3. If possible also has peaks in distal intron?
#
# Choose KHSRP (K562 dataset has more peaks than HepG2)
# ENCODE datasets ENCSR438GZQ (K562) and ENCSR366DGX (HepG2)

# %% [markdown]
# Open pyranges from `str_near_splice.ipynb`

# %%
within_300 = pr.PyRanges(pd.read_csv("within_300_ss_pyranges.csv"))
within_300.head()
# Out:
# +--------------+-----------+-----------+------------+-----------+-------+
# | Chromosome   |     Start |       End | class      |    length | +23   |
# | (category)   |   (int32) |   (int32) | (object)   |   (int64) | ...   |
# |--------------+-----------+-----------+------------+-----------+-------|
# | chr1         |     13623 |     13635 | ACAGGC     |        12 | ...   |
# | chr1         |    322376 |    322388 | AAGAAT     |        12 | ...   |
# | chr1         |    877247 |    877259 | AGGGG      |        12 | ...   |
# | chr1         |    879886 |    879906 | AGCCC      |        20 | ...   |
# | chr1         |    882085 |    882097 | AGAGGC     |        12 | ...   |
# | chr1         |    882362 |    882374 | AGATGG     |        12 | ...   |
# | chr1         |    882442 |    882456 | ACT        |        14 | ...   |
# | chr1         |    888115 |    888127 | ACCCCC     |        12 | ...   |
# +--------------+-----------+-----------+------------+-----------+-------+
# Stranded PyRanges object has 8 rows and 28 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 23 hidden columns: Strand, num_units, actual_repeat, gene_id, gene_start, gene_stop, ... (+ 17 more.)

# %%
intron_internal = pr.PyRanges(pd.read_csv("intron_internal_pyranges.csv"))
intron_internal.head()
# Out:
# +--------------+-----------+-----------+------------+-----------+-------+
# | Chromosome   |     Start |       End | class      |    length | +23   |
# | (category)   |   (int32) |   (int32) | (object)   |   (int64) | ...   |
# |--------------+-----------+-----------+------------+-----------+-------|
# | chr1         |     22811 |     22823 | AAAGG      |        12 | ...   |
# | chr1         |     23874 |     23886 | ACCTCC     |        12 | ...   |
# | chr1         |    669727 |    669739 | AAC        |        12 | ...   |
# | chr1         |    676490 |    676503 | AAAAG      |        13 | ...   |
# | chr1         |    700958 |    700970 | AAATAC     |        12 | ...   |
# | chr1         |    701123 |    701136 | A          |        13 | ...   |
# | chr1         |    701240 |    701253 | ACTCC      |        13 | ...   |
# | chr1         |    702159 |    702173 | AATC       |        14 | ...   |
# +--------------+-----------+-----------+------------+-----------+-------+
# Stranded PyRanges object has 8 rows and 28 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 23 hidden columns: Strand, num_units, actual_repeat, gene_id, gene_start, gene_stop, ... (+ 17 more.)

# %% [markdown]
# Went to ENCODE website and got IDR peak bed file for KHSRP, K562 (ENCSR438GZQ), file ENCFF871BYW

# %%
KHSRP_K562_idr = pr.read_bed("data/ENCFF871BYW.bed")
KHSRP_K562_idr.head()
# Out:
# +--------------+-----------+-----------+----------------+-----------+-------+
# | Chromosome   |     Start |       End | Name           |     Score | +5    |
# | (category)   |   (int32) |   (int32) | (object)       |   (int64) | ...   |
# |--------------+-----------+-----------+----------------+-----------+-------|
# | chr1         | 180003735 | 180003828 | KHSRP_K562_IDR |      1000 | ...   |
# | chr1         | 182811783 | 182811820 | KHSRP_K562_IDR |      1000 | ...   |
# | chr1         | 204499655 | 204499788 | KHSRP_K562_IDR |      1000 | ...   |
# | chr1         | 171483132 | 171483194 | KHSRP_K562_IDR |      1000 | ...   |
# | chr1         |  35835522 |  35835590 | KHSRP_K562_IDR |      1000 | ...   |
# | chr1         | 220296337 | 220296411 | KHSRP_K562_IDR |      1000 | ...   |
# | chr1         | 213278658 | 213278692 | KHSRP_K562_IDR |      1000 | ...   |
# | chr1         | 213278692 | 213278739 | KHSRP_K562_IDR |      1000 | ...   |
# +--------------+-----------+-----------+----------------+-----------+-------+
# Stranded PyRanges object has 8 rows and 10 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 5 hidden columns: Strand, ThickStart, ThickEnd, ItemRGB, BlockCount

# %%
# let's find KHSRP peaks that overlap with STRs near splice sites
KHSRP_STR_ss = within_300.overlap(KHSRP_K562_idr, strandedness = False)
print(len(KHSRP_STR_ss))
KHSRP_STR_ss.head()
# Out:
# 774
# +--------------+-----------+-----------+------------+-----------+-------+
# | Chromosome   |     Start |       End | class      |    length | +23   |
# | (category)   |   (int32) |   (int32) | (object)   |   (int64) | ...   |
# |--------------+-----------+-----------+------------+-----------+-------|
# | chr1         |  16202598 |  16202613 | AAAGAC     |        15 | ...   |
# | chr1         |  19431450 |  19431465 | AAAC       |        15 | ...   |
# | chr1         |  19472854 |  19472866 | AATGAC     |        12 | ...   |
# | chr1         |  19511411 |  19511423 | AACAGT     |        12 | ...   |
# | chr1         |  21103024 |  21103036 | AATCT      |        12 | ...   |
# | chr1         |  21267707 |  21267725 | AAC        |        18 | ...   |
# | chr1         |  22030960 |  22030972 | AAAACC     |        12 | ...   |
# | chr1         |  23637968 |  23637981 | AAACAC     |        13 | ...   |
# +--------------+-----------+-----------+------------+-----------+-------+
# Stranded PyRanges object has 8 rows and 28 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 23 hidden columns: Strand, num_units, actual_repeat, gene_id, gene_start, gene_stop, ... (+ 17 more.)

# %%
# let's find KHSRP peaks that overlap with intron-internal STRS
KHSRP_STR_internal = intron_internal.overlap(KHSRP_K562_idr, strandedness = False)
print(len(KHSRP_STR_internal))
KHSRP_STR_internal.head()
# Out:
# 1035
# +--------------+-----------+-----------+------------+-----------+-------+
# | Chromosome   |     Start |       End | class      |    length | +23   |
# | (category)   |   (int32) |   (int32) | (object)   |   (int64) | ...   |
# |--------------+-----------+-----------+------------+-----------+-------|
# | chr1         |   7893325 |   7893338 | AAATGT     |        13 | ...   |
# | chr1         |   8678244 |   8678257 | AACATC     |        13 | ...   |
# | chr1         |  21461506 |  21461521 | ATC        |        15 | ...   |
# | chr1         |  22064138 |  22064150 | AAAAC      |        12 | ...   |
# | chr1         |  25780207 |  25780221 | AAATTT     |        14 | ...   |
# | chr1         |  28334899 |  28334918 | AAAAC      |        19 | ...   |
# | chr1         |  28375972 |  28375984 | AAAAAC     |        12 | ...   |
# | chr1         |  29220915 |  29220927 | AATGTG     |        12 | ...   |
# +--------------+-----------+-----------+------------+-----------+-------+
# Stranded PyRanges object has 8 rows and 28 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 23 hidden columns: Strand, num_units, actual_repeat, gene_id, gene_start, gene_stop, ... (+ 17 more.)

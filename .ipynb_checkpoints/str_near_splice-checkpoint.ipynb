# %% [markdown]
# # Identify STRs that are at splice sites
# Like the ENCODE paper, define a splice site as being within 100bp of an exon. All of the following uses the GRCh37 alignments (GENCODE v19 annotations), also like the paper.
# Links to [GENCODE data](https://www.gencodegenes.org/human/release_37lift37.html)

# %%
import pyranges as pr
import numpy as np
import pandas as pd

# %% [markdown]
# Load the STR data

# %%
col_names = ["Chromosome", "Start", "End", "class", 
            "length", "Strand", "num_units", 
            "actual_repeat", "gene", "gene_start",
            "gene_stop", "gene_strand", "annotation",
            "promoter", "dist_to_tss"]
str_df = pd.read_csv("data/msdb_data.tsv", sep = '\t', names = col_names, index_col = False, na_values = "")
str_df.head()
# Out:
# /Users/david/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (9,10,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Chromosome  Start    End   class  length Strand  num_units actual_repeat  \
# 0       chr1  10000  10108  AACCCT     108      +         18        TAACCC
# 1       chr1  10108  10149  AACCCT      41      +          6        AACCCT
# 2       chr1  10147  10179  AACCCT      32      +          5        CCCTAA
# 3       chr1  10172  10184   AACCT      12      +          2         CCTAA
# 4       chr1  10177  10233  AACCCT      56      +          9        CCTAAC
#
#          gene gene_start gene_stop gene_strand  annotation      promoter  \
# 0  uc001aaa.3      11874     14409           +  Intergenic  Non-Promoter
# 1  uc001aaa.3      11874     14409           +  Intergenic  Non-Promoter
# 2  uc001aaa.3      11874     14409           +  Intergenic  Non-Promoter
# 3  uc001aaa.3      11874     14409           +  Intergenic  Non-Promoter
# 4  uc001aaa.3      11874     14409           +  Intergenic  Non-Promoter
#
#   dist_to_tss
# 0       -1766
# 1       -1725
# 2       -1695
# 3       -1690
# 4       -1641

# %%
str_pr = pr.PyRanges(str_df)
str_pr
# Out:
# +--------------+-----------+-----------+------------+-----------+--------------+-------------+-----------------+------------+--------------+-------------+---------------+--------------+-------+
# | Chromosome   | Start     | End       | class      | length    | Strand       | num_units   | actual_repeat   | gene       | gene_start   | gene_stop   | gene_strand   | annotation   | +2    |
# | (category)   | (int32)   | (int32)   | (object)   | (int64)   | (category)   | (int64)     | (object)        | (object)   | (object)     | (object)    | (object)      | (object)     | ...   |
# |--------------+-----------+-----------+------------+-----------+--------------+-------------+-----------------+------------+--------------+-------------+---------------+--------------+-------|
# | chr1         | 10000     | 10108     | AACCCT     | 108       | +            | 18          | TAACCC          | uc001aaa.3 | 11874        | 14409       | +             | Intergenic   | ...   |
# | chr1         | 10108     | 10149     | AACCCT     | 41        | +            | 6           | AACCCT          | uc001aaa.3 | 11874        | 14409       | +             | Intergenic   | ...   |
# | chr1         | 10147     | 10179     | AACCCT     | 32        | +            | 5           | CCCTAA          | uc001aaa.3 | 11874        | 14409       | +             | Intergenic   | ...   |
# | chr1         | 10172     | 10184     | AACCT      | 12        | +            | 2           | CCTAA           | uc001aaa.3 | 11874        | 14409       | +             | Intergenic   | ...   |
# | ...          | ...       | ...       | ...        | ...       | ...          | ...         | ...             | ...        | ...          | ...         | ...           | ...          | ...   |
# | chrY         | 59363501  | 59363513  | ACACCC     | 12        | -            | 2           | GTGTGG          | uc011ncc.1 | 59358329     | 59360854    | -             | Intergenic   | ...   |
# | chrY         | 59363514  | 59363543  | ACACCC     | 29        | -            | 4           | GTGTGG          | uc011ncc.1 | 59358329     | 59360854    | -             | Intergenic   | ...   |
# | chrY         | 59363540  | 59363552  | ACACCC     | 12        | -            | 2           | GTGTGG          | uc011ncc.1 | 59358329     | 59360854    | -             | Intergenic   | ...   |
# | chrY         | 59363553  | 59363565  | ACACCC     | 12        | -            | 2           | GTGTGG          | uc011ncc.1 | 59358329     | 59360854    | -             | Intergenic   | ...   |
# +--------------+-----------+-----------+------------+-----------+--------------+-------------+-----------------+------------+--------------+-------------+---------------+--------------+-------+
# Stranded PyRanges object has 4,396,272 rows and 15 columns from 92 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 2 hidden columns: promoter, dist_to_tss

# %% [markdown]
# Load the UCSC introns

# %%
col_names = ["Chromosome", "Start", "End", "ucsc_id", "unk", "Strand"]
intron_df = pd.read_csv("data/ucsc_introns.bed", sep = '\t', names = col_names, index_col = False, skiprows = [0])
intron_df.head()
# Out:
#   Chromosome  Start    End                             ucsc_id  unk Strand
# 0       chr1  12227  12612  uc001aaa.3_intron_0_0_chr1_12228_f    0      +
# 1       chr1  12721  13220  uc001aaa.3_intron_1_0_chr1_12722_f    0      +
# 2       chr1  12227  12645  uc010nxr.1_intron_0_0_chr1_12228_f    0      +
# 3       chr1  12697  13220  uc010nxr.1_intron_1_0_chr1_12698_f    0      +
# 4       chr1  12227  12594  uc010nxq.1_intron_0_0_chr1_12228_f    0      +

# %%
intron_pr = pr.PyRanges(intron_df)
intron_pr
# Out:
# +--------------+-----------+-----------+---------------------------------------+-----------+--------------+
# | Chromosome   | Start     | End       | ucsc_id                               | unk       | Strand       |
# | (category)   | (int32)   | (int32)   | (object)                              | (int64)   | (category)   |
# |--------------+-----------+-----------+---------------------------------------+-----------+--------------|
# | chr1         | 12227     | 12612     | uc001aaa.3_intron_0_0_chr1_12228_f    | 0         | +            |
# | chr1         | 12721     | 13220     | uc001aaa.3_intron_1_0_chr1_12722_f    | 0         | +            |
# | chr1         | 12227     | 12645     | uc010nxr.1_intron_0_0_chr1_12228_f    | 0         | +            |
# | chr1         | 12697     | 13220     | uc010nxr.1_intron_1_0_chr1_12698_f    | 0         | +            |
# | ...          | ...       | ...       | ...                                   | ...       | ...          |
# | chrY         | 27218868  | 27245878  | uc011nbv.2_intron_2_0_chrY_27218869_r | 0         | -            |
# | chrY         | 27329895  | 27330860  | uc004fwt.3_intron_0_0_chrY_27329896_r | 0         | -            |
# | chrY         | 59359508  | 59360006  | uc011ncc.1_intron_0_0_chrY_59359509_r | 0         | -            |
# | chrY         | 59360115  | 59360500  | uc011ncc.1_intron_1_0_chrY_59360116_r | 0         | -            |
# +--------------+-----------+-----------+---------------------------------------+-----------+--------------+
# Stranded PyRanges object has 659,327 rows and 6 columns from 54 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.

# %% [markdown]
# Next, get all the intervals of short tandem repeats that are located in introns. The new PyRanges Start, End will now reflect only the region of the repeat that overlapped the intron, not the length of the whole repeat (this information is retained in the `length` column)

# %%
str_intron_intersect = str_pr.intersect(intron_pr, strandedness= False)

# %%
str_intron_intersect
# drop duplicate rows in the intersection PyRanges
str_intron_intersect_nodup = str_intron_intersect.drop_duplicate_positions()
str_intron_intersect_nodup
# Out:
# +--------------+-----------+-----------+------------+-----------+--------------+-------------+-----------------+------------+--------------+-------------+---------------+--------------+-------+
# | Chromosome   | Start     | End       | class      | length    | Strand       | num_units   | actual_repeat   | gene       | gene_start   | gene_stop   | gene_strand   | annotation   | +2    |
# | (category)   | (int32)   | (int32)   | (object)   | (int64)   | (category)   | (int64)     | (object)        | (object)   | (object)     | (object)    | (object)      | (object)     | ...   |
# |--------------+-----------+-----------+------------+-----------+--------------+-------------+-----------------+------------+--------------+-------------+---------------+--------------+-------|
# | chr1         | 15240     | 15255     | AGGGCC     | 15        | +            | 2           | GGGCCA          | uc009viv.2 | 14407        | 29370       | -             | Exon         | ...   |
# | chr1         | 15383     | 15395     | AGGCGC     | 12        | +            | 2           | GCAGGC          | uc009viv.2 | 14407        | 29370       | -             | Exon         | ...   |
# | chr1         | 17476     | 17488     | AGCCG      | 12        | +            | 2           | CCGAG           | uc009vjc.1 | 16858        | 17751       | -             | Exon         | ...   |
# | chr1         | 17801     | 17814     | ATCCC      | 13        | +            | 2           | CCATC           | uc009vjd.2 | 15796        | 18061       | -             | Exon         | ...   |
# | ...          | ...       | ...       | ...        | ...       | ...          | ...         | ...             | ...        | ...          | ...         | ...           | ...          | ...   |
# | chrY         | 59354264  | 59354277  | AGGCC      | 13        | -            | 2           | GGCCT           | uc004fxo.1 | 59352973     | 59356131    | +             | Intron       | ...   |
# | chrY         | 59355249  | 59355261  | AGCCG      | 12        | -            | 2           | GGCTC           | uc022cpg.1 | 59354985     | 59358336    | +             | Intron       | ...   |
# | chrY         | 59357345  | 59357357  | AGGCGC     | 12        | -            | 2           | GCCTGC          | uc022cpg.1 | 59354985     | 59358336    | +             | Intron       | ...   |
# | chrY         | 59357485  | 59357500  | AGGGCC     | 15        | -            | 2           | CCCTGG          | uc022cpg.1 | 59354985     | 59358336    | +             | Intron       | ...   |
# +--------------+-----------+-----------+------------+-----------+--------------+-------------+-----------------+------------+--------------+-------------+---------------+--------------+-------+
# Stranded PyRanges object has 1,973,762 rows and 15 columns from 53 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 2 hidden columns: promoter, dist_to_tss

# %% [markdown]
# Next, want to get the eCLIP peaks that are in these STRs
